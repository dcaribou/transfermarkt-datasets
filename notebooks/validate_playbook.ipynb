# %%
import pandas as pd

validate_file = "players"
joining_keys = ["player_id"]

old = pd.read_csv(f"/Users/dcereijo/transfermarkt-datasets/data/prep/{validate_file}.csv")
new = pd.read_csv(f"/Users/dcereijo/transfermarkt-datasets/data/prep_2/{validate_file}.csv")

# %%
import datacompy

# %%
comparison = datacompy.Compare(
    df1=old,
    df2=new,
    join_columns=joining_keys
)

# %%
print(comparison.report())
# Out:
# DataComPy Comparison
# --------------------
#
# DataFrame Summary
# -----------------
#
#   DataFrame  Columns   Rows
# 0       df1       23  28503
# 1       df2       20  27246
#
# Column Summary
# --------------
#
# Number of columns in common: 20
# Number of columns in df1 but not in df2: 3
# Number of columns in df2 but not in df1: 0
#
# Row Summary
# -----------
#
# Matched on: player_id
# Any duplicates on match values: No
# Absolute Tolerance: 0
# Relative Tolerance: 0
# Number of rows in common: 27,246
# Number of rows in df1 but not in df2: 1,257
# Number of rows in df2 but not in df1: 0
#
# Number of rows with some compared columns unequal: 27,246
# Number of rows with all compared columns equal: 0
#
# Column Comparison
# -----------------
#
# Number of columns compared with some values unequal: 14
# Number of columns compared with all values equal: 6
# Total number of values which compare unequal: 82,017
#
# Columns with Unequal Values or Types
# ...

# %%
set(old.columns.values) - set(new.columns.values)
# Out:
# {'contract_expiration_date',
#  'highest_market_value_in_eur',
#  'market_value_in_eur'}
